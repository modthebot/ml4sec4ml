# %% [markdown]
# <a href="https://colab.research.google.com/github/modthebot/ml4sec4ml/blob/master/Unintended_Memorization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 18.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.0/295.0 kB 31.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 42.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 48.5 MB/s eta 0:00:00
# ...

# %%
from transformers import pipeline, set_seed
generator = pipeline('text-generation', model='gpt2-large')

# %%
pi = '3....'
len(pi)
# Out:
# 2390

# %%
set_seed(52)
gen_samples = generator("3.1415926535", max_length=60, num_return_sequences=2)
for sample in gen_samples:
    if pi[:45] in sample['generated_text']:
        print(sample['generated_text'])
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 3.141592653589793238462643383279502884197169399375103844602884197162693993751038446602803484560328425286462875 6627034462376411172791453038

# %%
len('3.14159265358979323846264338327950288419716939937510582097494') - 12
# Out:
# 49
